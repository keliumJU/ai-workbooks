# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data and Split

# %%
X = [[1,2], [1,3], [2,2], [2,3], [3,1]]
y = [0,0,1,1,0]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # Grid search

# %%
param_grid = {'n_estimators': [50, 100], 'max_depth': [None, 10]}
grid_search = GridSearchCV(RandomForestClassifier(), param_grid, scoring='accuracy', cv=2)
grid_search.fit(X_train, y_train)

print("Best parameters: ", grid_search.best_params_)
print("Best cross-validated accuracy: ", grid_search.best_score_)
# Out:
# /home/norn/Documents/ai-agents-python/myenv/lib64/python3.13/site-packages/sklearn/model_selection/_split.py:813: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# Best parameters:  {'max_depth': None, 'n_estimators': 100}
# Best cross-validated accuracy:  0.5
