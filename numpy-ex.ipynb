# %%
import numpy as np

# %% [markdown]
# # Create arrays

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %% [markdown]
# # Perform element-wise addition

# %%
result = a+b
print(result)
# Out:
# [5 7 9]
